# %% [markdown]
# # Team GPT
#
# ## Table of Contents
#
# - [Overview](#overview)
# - [World Map](#world-map)
# - [Roles](#roles)
#
# ## Overview
#
# The [Dev Launchers](https://devlaunchers.org) website is a community of aspiring developers eager to learn and gain experience. As such, projects are open-source and ambitious, allowing members to enhance their skills.
#
# The [ChatBot](https://en.wikipedia.org/wiki/Chatbot) project is valuable to this international community working across different time zones. To integrate a new member, it is crucial to be able to address their questions. This becomes challenging when the part of the community capable of responding is located 12 time zones away from the new member. Therefore, it was essential to have a service capable of answering questions, even in the middle of the night.
#
# ## World Map

# %%
import folium

# Coordinates of locations (latitude, longitude) and UTC zones.
# https://en.wikipedia.org/wiki/List_of_tz_database_time_zones
emplacements = [
    {"nom": "Chung T. H.", "role": "Co-founder", "latitude": 38.7369, "longitude": -9.1426, "utc_std": "0", "utc_dst": "+1", "place": "Lisbon"},
    {"nom": "Gauthier R.", "role": "GPT Team Tech Lead", "latitude": 46.2043, "longitude": 6.1431, "utc_std": "+1", "utc_dst": "+2", "place": "Geneva"},
    {"nom": "Gauri T.", "role": "UI/UX Designer", "latitude": 39.7910, "longitude": -86.1480, "utc_std": "-5", "utc_dst": "-4", "place": "Indianapolis"},
    {"nom": "Harrison Mc.", "role": "Full Stack Developer", "latitude": 42.6525, "longitude": -73.7562, "utc_std": "-5", "utc_dst": "-4", "place": "Albany"},
    {"nom": "Purushotham R.", "role": "Data Scientist", "latitude": 39.2992, "longitude": -76.6093, "utc_std": "-5", "utc_dst": "-4", "place": "Baltimore"},
]

# Creation of the map using Folium.
m = folium.Map(location=[emplacements[0]["latitude"], emplacements[0]["longitude"]], zoom_start=3)

# Adding markers for each location.
for e in emplacements:
    html = f"""<div style="font-family: sans-serif;">
                   <p style="font-size: 20px; font-weight: bold">{e['nom']}</p>
                   <p style="font-size: 16px; font-weight: bold">{e['role']}</p>
                   <p>UTC: ❄️{e['utc_std']}, ☀️{e['utc_dst']}</p>
                   <p style="font-size: 16px; font-weight: bold; color: grey;">📍 {e['place']}</p>
                </div>
            """
    iframe = folium.IFrame(html=html, width=300, height=150)  # Correction de la virgule ici
    folium.Marker(
        location=[e["latitude"], e["longitude"]],
        popup=folium.Popup(iframe, min_width=300, max_width=300),
        icon=folium.Icon(color="blue", icon="info-sign"),
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_30e58e281f6086448660adce0d6db6f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_30e58e281f6086448660adce0d6db6f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_30e58e281f6086448660adce0d6db6f9 = L.map(
#                 &quot;map_30e58e281f6086448660adce0d6db6f9&quot;,
#                 {
#                     center: [38.7369, -9.1426],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c8ddc37b528e3abad1c103b94680f2b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7c8ddc37b528e3abad1c103b94680f2b.addTo(map_30e58e281f6086448660adce0d6db6f9);
#
#
#             var marker_e3add2521a08219d987e828682a87d97 = L.marker(
#                 [38.7369, -9.1426],
#                 {}
#             ).addTo(map_30e58e281f6086448660adce0d6db6f9);
#
#
#             var icon_dc55f8b4d5a99ebdbf078f17cae04798 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e3add2521a08219d987e828682a87d97.setIcon(icon_dc55f8b4d5a99ebdbf078f17cae04798);
#
#
#         var popup_90a7de4e1a57d6b0572b4f9b4315acd6 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_cf9609321bd7102f8899400da2ac96b8 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_90a7de4e1a57d6b0572b4f9b4315acd6.setContent(i_frame_cf9609321bd7102f8899400da2ac96b8);
#
#
#
#         marker_e3add2521a08219d987e828682a87d97.bindPopup(popup_90a7de4e1a57d6b0572b4f9b4315acd6)
#         ;
#
#
#
#
#             var marker_416e894b8bf9317242b3eecb7ec4713b = L.marker(
#                 [46.2043, 6.1431],
#                 {}
#             ).addTo(map_30e58e281f6086448660adce0d6db6f9);
#
#
#             var icon_bc034191ea92ce716a5ac745ba55501a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_416e894b8bf9317242b3eecb7ec4713b.setIcon(icon_bc034191ea92ce716a5ac745ba55501a);
#
#
#         var popup_5bb93664a48b0ff570fac1e19d5504dc = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_4786dec5738e39e709dede498d9207aa = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_5bb93664a48b0ff570fac1e19d5504dc.setContent(i_frame_4786dec5738e39e709dede498d9207aa);
#
#
#
#         marker_416e894b8bf9317242b3eecb7ec4713b.bindPopup(popup_5bb93664a48b0ff570fac1e19d5504dc)
#         ;
#
#
#
#
#             var marker_bc5353dfded6f30c571907704d25d9d3 = L.marker(
#                 [39.791, -86.148],
#                 {}
#             ).addTo(map_30e58e281f6086448660adce0d6db6f9);
#
#
#             var icon_dd69e56e2cebd45765f3cb0dad8a15e3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bc5353dfded6f30c571907704d25d9d3.setIcon(icon_dd69e56e2cebd45765f3cb0dad8a15e3);
#
#
#         var popup_117efdb1a07c567ba132b80caf686bf7 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_fc27ae8156e68e8a8fe6c956ab3c3efe = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_117efdb1a07c567ba132b80caf686bf7.setContent(i_frame_fc27ae8156e68e8a8fe6c956ab3c3efe);
#
#
#
#         marker_bc5353dfded6f30c571907704d25d9d3.bindPopup(popup_117efdb1a07c567ba132b80caf686bf7)
#         ;
#
#
#
#
#             var marker_ac8648f2f0cf24072a6f3be1b7380688 = L.marker(
#                 [42.6525, -73.7562],
#                 {}
#             ).addTo(map_30e58e281f6086448660adce0d6db6f9);
#
#
#             var icon_8b79114507620386b41afd18faae2913 = L.AwesomeMarkers.icon(
#                 {&quot

# %% [markdown]
# ## Roles
#
# **Chung T. H.** (Co-founder)
# * Initiates project ideas
# * Coordinates projects and teams
# * Recruits new team members
#
# **Gauri T.** (UI/UX Designer)
# * Designs the interface
# * Creates the avatar and its animations
# * Leads research on the character's personality
#
# **Gauthier R.** (GPT Team Tech Lead)
# * Coordinates the technical aspects of the project
# * Researches Open-source models and fine-tuning
# * Investigates Retrieval-Augmented Generator (RAG) and document provisioning
#
# **Harrison Mc.** (Full Stack Developer)
# * Works on deploying a RAG based on ChatGPT
# * Codes the user interface on both the front and back end
# * Implements the solution in production on the website
#
# **Purushotham R.** (Data Scientist)
# * Researches Open-source models
# * Investigates RAG and document provisioning
# * Focuses on optimizing models
